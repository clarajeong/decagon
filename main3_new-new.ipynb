# %%
from __future__ import division
from __future__ import print_function
from operator import itemgetter
from itertools import combinations
import time
import os

import tensorflow.compat.v1 as tf

import numpy as np
import networkx as nx
import scipy.sparse as sp
from sklearn import metrics

from decagon.deep.optimizer import DecagonOptimizer
from decagon.deep.model import DecagonModel
from decagon.deep.minibatch import EdgeMinibatchIterator
from decagon.utility import rank_metrics, preprocessing

tf.disable_eager_execution()

########## scipy: version 1.9로 바꿔야함

#깔아야하는 packages
#networkx
#scikit-learn
#tensorflow

# Train on CPU (hide GPU) due to memory constraints
# os.environ['CUDA_VISIBLE_DEVICES'] = ""

# Train on GPU
os.environ["CUDA_DEVICE_ORDER"] = 'PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

np.random.seed(0)

# %%
###########################################################
#
# Functions
#
###########################################################


def get_accuracy_scores(edges_pos, edges_neg, edge_type):
    feed_dict.update({placeholders['dropout']: 0})
    feed_dict.update({placeholders['batch_edge_type_idx']: minibatch.edge_type2idx[edge_type]})
    feed_dict.update({placeholders['batch_row_edge_type']: edge_type[0]})
    feed_dict.update({placeholders['batch_col_edge_type']: edge_type[1]})
    rec = sess.run(opt.predictions, feed_dict=feed_dict)

    def sigmoid(x):
        return 1. / (1 + np.exp(-x))

    # Predict on test set of edges
    preds = []
    actual = []
    predicted = []
    edge_ind = 0
    for u, v in edges_pos[edge_type[:2]][edge_type[2]]:
        score = sigmoid(rec[u, v])
        preds.append(score)
        assert adj_mats_orig[edge_type[:2]][edge_type[2]][u,v] == 1, 'Problem 1'

        actual.append(edge_ind)
        predicted.append((score, edge_ind))
        edge_ind += 1

    preds_neg = []
    for u, v in edges_neg[edge_type[:2]][edge_type[2]]:
        score = sigmoid(rec[u, v])
        preds_neg.append(score)
        assert adj_mats_orig[edge_type[:2]][edge_type[2]][u,v] == 0, 'Problem 0'

        predicted.append((score, edge_ind))
        edge_ind += 1

    preds_all = np.hstack([preds, preds_neg])
    preds_all = np.nan_to_num(preds_all)
    labels_all = np.hstack([np.ones(len(preds)), np.zeros(len(preds_neg))])
    predicted = list(zip(*sorted(predicted, reverse=True, key=itemgetter(0))))[1]

    roc_sc = metrics.roc_auc_score(labels_all, preds_all)
    aupr_sc = metrics.average_precision_score(labels_all, preds_all)
    apk_sc = rank_metrics.apk(actual, predicted, k=50)

    return roc_sc, aupr_sc, apk_sc


def construct_placeholders(edge_types):
    placeholders = {
        'batch': tf.placeholder(tf.int32, name='batch'),
        'batch_edge_type_idx': tf.placeholder(tf.int32, shape=(), name='batch_edge_type_idx'),
        'batch_row_edge_type': tf.placeholder(tf.int32, shape=(), name='batch_row_edge_type'),
        'batch_col_edge_type': tf.placeholder(tf.int32, shape=(), name='batch_col_edge_type'),
        'degrees': tf.placeholder(tf.int32),
        'dropout': tf.placeholder_with_default(0., shape=()),
    }
    placeholders.update({
        'adj_mats_%d,%d,%d' % (i, j, k): tf.sparse_placeholder(tf.float32)
        for i, j in edge_types for k in range(edge_types[i,j])})
    placeholders.update({
        'feat_%d' % i: tf.sparse_placeholder(tf.float32)
        for i, _ in edge_types})
    return placeholders

# %%
###########################################################
#
# Load and preprocess data (This is a dummy toy example!)
#
###########################################################

####
# The following code uses artificially generated and very small networks.
# Expect less than excellent performance as these random networks do not have any interesting structure.
# The purpose of main.py is to show how to use the code!
#
# All preprocessed datasets used in the drug combination study are at: http://snap.stanford.edu/decagon:
# (1) Download datasets from http://snap.stanford.edu/decagon to your local machine.
# (2) Replace dummy toy datasets used here with the actual datasets you just downloaded.
# (3) Train & test the model.
####

val_test_size = 0.05

# %%
import csv

# for line in reader:

# %%
import pandas as pd

# %%
gene_max = 0
drug_max = 0

df_ppi = pd.read_csv('/mnt/nas2/seogyeong/bio-decagon-ppi.csv', sep=',', header=0)
df_targets = pd.read_csv('/mnt/nas2/seogyeong/bio-decagon-targets-all.csv', sep=',', header=0)
df_combo = pd.read_csv('/mnt/nas2/seogyeong/bio-decagon-combo.csv', sep=',', header=0)

print(df_ppi.values.T[0].shape)
print(df_ppi.values.T[1].shape)
print(df_targets.values.T[1].shape)
temp = list(df_ppi.values.T[0])
temp.extend(list(df_ppi.values.T[1]))
temp.extend(list(df_targets.values.T[1]))

gene_set = set(temp)
# print(gene_set)


temp = list(df_combo.values.T[0])
temp.extend(list(df_combo.values.T[1]))
temp.extend(list(df_targets.values.T[0]))
drug_set = set(temp)
# print(drug_set)

print("numbers")
gene_n = len(gene_set)
drug_n = len(drug_set)
print(gene_n, drug_n)

print("max")
gene_max = max(gene_set)
drug_max = 0 
for drugs in drug_set:
    # print(drugs)
    # print(drugs[3:])
    if drug_max < int(drugs[3:]):
        drug_max = int(drugs[3:])
print(gene_max)
print(drug_max)
# Out:
# (715612,)
# (715612,)
# (131034,)
# numbers
# 19122 2135
# max
# 110255169
# 154677977

# %%
hashtable_gene = np.zeros(2* gene_n)
hashtable_drug = np.zeros(2* drug_n)

# %%
#make hash
count = 0
for genes in gene_set:
    n = genes % (2* gene_n)
    if count % 500 == 0:
        print(count, ", ",genes)
    count = count + 1
    while hashtable_gene[n] !=0:
        n = n+11
        if n >= 2* gene_n:
            n = n % 11
    hashtable_gene[n] = genes
# Out:
# 0 ,  1
# 500 ,  6636
# 1000 ,  1233
# 1500 ,  1903
# 2000 ,  2651
# 2500 ,  3248
# 3000 ,  3890
# 3500 ,  4626
# 4000 ,  5241
# 4500 ,  5864
# 5000 ,  399694
# 5500 ,  7026
# 6000 ,  7620
# 6500 ,  8483
# 7000 ,  9087
# 7500 ,  9667
# 8000 ,  10211
# 8500 ,  10815
# 9000 ,  339559
# 9500 ,  79689
# 10000 ,  80312
# 10500 ,  114571
# 11000 ,  23066
# 11500 ,  51204
# 12000 ,  51725
# 12500 ,  85406
# 13000 ,  283643
# 13500 ,  284370
# 14000 ,  55626
# 14500 ,  23357
# 15000 ,  56903
# 15500 ,  57540
# 16000 ,  124056
# 16500 ,  26338
# 17000 ,  158293
# 17500 ,  126626
# 18000 ,  160857
# 18500 ,  129450
# 19000 ,  27333

# %%
print(hashtable_gene)

count = 0
for drugs in drug_set:
    
    if count % 500 == 0:
        print(count, ", ",drugs)
    count = count + 1
    
    n = int(drugs[3:]) % (2* drug_n)
    while hashtable_drug[n] !=0:
        n = n + 11
        if n >= 2* drug_n:
            n = n % 11
    hashtable_drug[n] = int(drugs[3:])


print(hashtable_drug)
# Out:
# [0. 1. 2. ... 0. 0. 0.]
# 0 ,  CID000065856
# 500 ,  CID000002232
# 1000 ,  CID000039764
# 1500 ,  CID100001775
# 2000 ,  CID006323490
# [0.00000000e+00 1.00003355e+08 0.00000000e+00 ... 1.00003397e+08
#  1.00024748e+08 1.00003399e+08]

# %%
def hash_gene(gene_id):
    n = gene_id % (2* gene_n)
    while hashtable_gene[n] != gene_id:
        n = n+11
        if n >= 2*gene_n:
            n = n % 11
    return n

def hash_drug(drug_id):
    n = int(drug_id[3:]) % (2* drug_n)
    while hashtable_drug[n] != int(drug_id[3:]):
        n = n+11
        if n >= 2* drug_n:
            n = n % 11
    return n

# %%
# protein-protein


gene_adj = sp.csr_matrix((2* gene_n, 2* gene_n), dtype=np.int8)

a =  0

f = open("/mnt/nas2/seogyeong/bio-decagon-ppi.csv")
reader = csv.reader(f)
count = 0

print(gene_adj)
print(gene_adj.shape)

for line in reader:
    #print(line)
    count = count + 1
    if a==0:
        a=1
        continue
    if count % 5000 == 0:
        print("count: ",count, ", ", line)
        break
        #여기지우기 꼭!
    gene_adj[hash_gene(int(line[0])), hash_gene(int(line[1]))] = 1
print("hey")
print(gene_adj)
gene_degrees = np.array(gene_adj.sum(axis=0)).squeeze()
print(gene_degrees)
# print(df)
# Out:
# (38244, 38244)
# /root/anaconda3/lib/python3.9/site-packages/scipy/sparse/_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# count:  5000 ,  ['6790', '7324']
# hey
#   (57, 974)	1
#   (57, 2795)	1
#   (57, 3598)	1
#   (57, 3914)	1
#   (57, 4035)	1
#   (57, 6272)	1
#   (57, 6564)	1
#   (57, 10482)	1
#   (57, 10492)	1
#   (57, 10988)	1
#   (57, 23012)	1
#   (63, 25)	1
#   (63, 1398)	1
#   (63, 2534)	1
#   (63, 4690)	1
#   (63, 5335)	1
#   (64, 1994)	1
#   (64, 3013)	1
#   (64, 3054)	1
#   (64, 3607)	1
#   (64, 5928)	1
#   (64, 6233)	1
#   (64, 7311)	1
#   (64, 7314)	1
#   (64, 8314)	1
#   :	:
#   (36007, 5437)	1
#   (36007, 5440)	1
#   (36007, 5441)	1
#   (36007, 6908)	1
#   (36007, 6932)	1
#   (36007, 9329)	1
#   (36007, 9339)	1
#   (36007, 9341)	1
#   (36007, 9533)	1
#   (36007, 10482)	1
#   (36007, 10621)	1
#   (36007, 10622)	1
#   (36007, 11128)	1
#   (36007, 11385)	1
#   (36007, 12838)	1
#   (36007, 13484)	1
#   (36007, 15272)	1
#   (36007, 15737)	1
#   (36007, 17474)	1
#   (36007, 17492)	1
#   (36007, 17665)	1
#   (36007, 18592)	1
#   (36007, 20249)	1
#   (36007, 23524)	1
#   (36007, 27297)	1
# [0 1 0 ... 0 0 0]

# %%
#protein-protein check
print("1")
print(gene_adj)
print("2")

f.close()
# Out:
# 1
#   (57, 974)	1
#   (57, 2795)	1
#   (57, 3598)	1
#   (57, 3914)	1
#   (57, 4035)	1
#   (57, 6272)	1
#   (57, 6564)	1
#   (57, 10482)	1
#   (57, 10492)	1
#   (57, 10988)	1
#   (57, 23012)	1
#   (63, 25)	1
#   (63, 1398)	1
#   (63, 2534)	1
#   (63, 4690)	1
#   (63, 5335)	1
#   (64, 1994)	1
#   (64, 3013)	1
#   (64, 3054)	1
#   (64, 3607)	1
#   (64, 5928)	1
#   (64, 6233)	1
#   (64, 7311)	1
#   (64, 7314)	1
#   (64, 8314)	1
#   :	:
#   (36007, 5437)	1
#   (36007, 5440)	1
#   (36007, 5441)	1
#   (36007, 6908)	1
#   (36007, 6932)	1
#   (36007, 9329)	1
#   (36007, 9339)	1
#   (36007, 9341)	1
#   (36007, 9533)	1
#   (36007, 10482)	1
#   (36007, 10621)	1
#   (36007, 10622)	1
#   (36007, 11128)	1
#   (36007, 11385)	1
#   (36007, 12838)	1
#   (36007, 13484)	1
#   (36007, 15272)	1
#   (36007, 15737)	1
#   (36007, 17474)	1
#   (36007, 17492)	1
#   (36007, 17665)	1
#   (36007, 18592)	1
#   (36007, 20249)	1
#   (36007, 23524)	1
#   (36007, 27297)	1
# 2

# %%
# gene_drug_adj = sp.csr_matrix((10 * np.random.randn(n_genes, n_drugs) > 15).astype(int))
# drug_gene_adj = gene_drug_adj.transpose(copy=True)

f = open("/mnt/nas2/seogyeong/bio-decagon-targets-all.csv")
reader = csv.reader(f)
gene_drug_adj = sp.csr_matrix((2* gene_n, 2* drug_n), dtype=np.int8)

a =  0
count = 0
for line in reader:
    #print(line)
    count = count + 1
    if a==0:
        a=1
        continue
    if count % 5000 == 0:
        print("count: ",count, ", ", line)
        break
        #여기지우기 꼭!
    gene_drug_adj[hash_gene(int(line[1])), hash_drug(line[0])] = 1
print("hey")
print(gene_drug_adj)
drug_gene_adj = gene_drug_adj.transpose(copy=True)
f.close()
# Out:
# count:  5000 ,  ['CID100003510', '1145']
# hey
#   (13, 271)	1
#   (15, 271)	1
#   (26, 271)	1
#   (26, 2803)	1
#   (30, 271)	1
#   (31, 271)	1
#   (32, 271)	1
#   (34, 271)	1
#   (35, 271)	1
#   (36, 271)	1
#   (37, 271)	1
#   (38, 271)	1
#   (39, 271)	1
#   (48, 961)	1
#   (49, 271)	1
#   (50, 961)	1
#   (54, 271)	1
#   (58, 271)	1
#   (59, 271)	1
#   (60, 271)	1
#   (69, 271)	1
#   (69, 961)	1
#   (70, 271)	1
#   (71, 271)	1
#   (72, 271)	1
#   :	:
#   (36574, 1184)	1
#   (36581, 271)	1
#   (36691, 271)	1
#   (36732, 271)	1
#   (36799, 271)	1
#   (36898, 271)	1
#   (36917, 271)	1
#   (36940, 271)	1
#   (36957, 271)	1
#   (36967, 271)	1
#   (36969, 271)	1
#   (36974, 271)	1
#   (36981, 271)	1
#   (36993, 271)	1
#   (37010, 271)	1
#   (37114, 271)	1
#   (37124, 271)	1
#   (37124, 1498)	1
#   (37124, 2072)	1
#   (37187, 271)	1
#   (37347, 271)	1
#   (37538, 271)	1
#   (37624, 271)	1
#   (37685, 271)	1
#   (37753, 271)	1

# %%
#drug_gene check
print("1")
print(gene_drug_adj)
print("2")
# Out:
# 1
#   (13, 271)	1
#   (15, 271)	1
#   (26, 271)	1
#   (26, 2803)	1
#   (30, 271)	1
#   (31, 271)	1
#   (32, 271)	1
#   (34, 271)	1
#   (35, 271)	1
#   (36, 271)	1
#   (37, 271)	1
#   (38, 271)	1
#   (39, 271)	1
#   (48, 961)	1
#   (49, 271)	1
#   (50, 961)	1
#   (54, 271)	1
#   (58, 271)	1
#   (59, 271)	1
#   (60, 271)	1
#   (69, 271)	1
#   (69, 961)	1
#   (70, 271)	1
#   (71, 271)	1
#   (72, 271)	1
#   :	:
#   (36574, 1184)	1
#   (36581, 271)	1
#   (36691, 271)	1
#   (36732, 271)	1
#   (36799, 271)	1
#   (36898, 271)	1
#   (36917, 271)	1
#   (36940, 271)	1
#   (36957, 271)	1
#   (36967, 271)	1
#   (36969, 271)	1
#   (36974, 271)	1
#   (36981, 271)	1
#   (36993, 271)	1
#   (37010, 271)	1
#   (37114, 271)	1
#   (37124, 271)	1
#   (37124, 1498)	1
#   (37124, 2072)	1
#   (37187, 271)	1
#   (37347, 271)	1
#   (37538, 271)	1
#   (37624, 271)	1
#   (37685, 271)	1
#   (37753, 271)	1
# 2

# %%
# drug_drug check


#drug_drug_adj_list = []
#tmp = np.dot(drug_gene_adj, gene_drug_adj)
#for i in range(n_drugdrug_rel_types):
#    mat = np.zeros((n_drugs, n_drugs))
#    for d1, d2 in combinations(list(range(n_drugs)), 2):
#        if tmp[d1, d2] == i + 4:
#            mat[d1, d2] = mat[d2, d1] = 1.
#    drug_drug_adj_list.append(sp.csr_matrix(mat))
#    print("hmm")
#    print(drug_drug_adj_list)
# drug_degrees_list = [np.array(drug_adj.sum(axis=0)).squeeze() for drug_adj in drug_drug_adj_list]


drug_drug_adj_list = []

# category
df = pd.read_csv('/mnt/nas2/seogyeong/bio-decagon-effectcategories.csv', sep=',', header=0)
print(type(df.values))
print(df.values.T[0])
category = df.values.T[0]

category_count = 0

for cat in category:
    print("category_count: ", category_count, ", ", cat)
    gene_drug_adj = sp.csr_matrix((2* drug_n, 2* drug_n), dtype=np.int8)
    f = open("/mnt/nas2/seogyeong/bio-decagon-combo.csv")
    reader = csv.reader(f)
    category_count = category_count + 1
    for line in reader:
        if line[2] == cat:
            gene_drug_adj[hash_drug(line[0]), hash_drug(line[1]) ] = 1
            gene_drug_adj[hash_drug(line[1]), hash_drug(line[0]) ] = 1
    drug_drug_adj_list.append(gene_drug_adj)
    f.close()
    
    if category_count == 10:
        break
        #여기지우기 꼭!
drug_degrees_list = [np.array(drug_adj.sum(axis=0)).squeeze() for drug_adj in drug_drug_adj_list]

print(drug_drug_adj_list)
print("GHHHHHHHHHHHHHHHHH")
print(drug_degrees_list)
# Out:
# <class 'numpy.ndarray'>
# ['C0017152' 'C0027858' 'C0041466' 'C0032807' 'C0033860' 'C0259749'
#  'C0349231' 'C0027726' 'C0024437' 'C0024312' 'C0020635' 'C0002878'
#  'C0003873' 'C0003872' 'C0002871' 'C0030446' 'C0002874' 'C0029429'
#  'C0019693' 'C0038013' 'C0018916' 'C0038019' 'C0008449' 'C0003486'
#  'C0009768' 'C0004030' 'C0002170' 'C0009763' 'C0031350' 'C0476089'
#  'C1527407' 'C0017658' 'C0013295' 'C0013298' 'C0000889' 'C0038454'
#  'C0019284' 'C0017574' 'C0011636' 'C0035258' 'C0011633' 'C0027051'
#  'C0007642' 'C0025290' 'C0025297' 'C0042594' 'C0010043' 'C0242225'
#  'C0034951' 'C0021345' 'C0025362' 'C0019212' 'C0019196' 'C0034494'
#  'C0014130' 'C0023798' 'C0006271' 'C0040262' 'C0011849' 'C0006277'
#  'C0016053' 'C0040558' 'C0020565' 'C0020445' 'C0023646' 'C0027086'
#  'C0014553' 'C0014550' 'C0162529' 'C0022568' 'C0018099' 'C0022603'
#  'C0034931' 'C0242172' 'C0034072' 'C0149756' 'C0031538' 'C0155540'
#  'C0023891' 'C0023890' 'C0023892' 'C0023895' 'C0030486' 'C0022665'
#  'C0014038' 'C0022667' 'C0007570' 'C0032310' 'C0027868' 'C0017601'
#  'C0017605' 'C0036416' 'C0022116' 'C1370740' 'C0032580' 'C0040128'
#  'C0030319' 'C0030312' 'C0041976' 'C1257843' 'C0040046' 'C0024228'
#  'C0027819' 'C0005747' 'C0013146' 'C0027813' 'C0031099' 'C0001339'
#  'C0031090' 'C0035455' 'C0018824' 'C1378703' 'C0019159' 'C0271650'
#  'C0026764' 'C0019151' 'C0026769' 'C0024141' 'C0031117' 'C0006012'
#  'C0002884' 'C0025160' 'C0035078' 'C0152013' 'C0152018' 'C0085166'
#  'C0151620' 'C0033578' 'C0034212' 'C0038238' 'C0848558' 'C0004690'
#  'C0015695' 'C0034359' 'C0442874' 'C0162565' 'C0005586' 'C0009375'
#  'C0010930' 'C0023903' 'C0007933' 'C0027404' 'C0001418' 'C0040259'
#  'C0702166' 'C0035854' 'C0014869' 'C0020532' 'C0020538' 'C0740394'
#  'C0011882' 'C0011880' 'C0011884' 'C0034186' 'C0156273' 'C0017160'
#  'C0227791' 'C0037023' 'C0018021' 'C0017168' 'C0014488' 'C0027719'
#  'C0011127' 'C0600139' 'C0013592' 'C0035920' 'C0022658' 'C0206062'
#  'C0007117' 'C0023530' 'C0029434' 'C0235974' 'C0003708' 'C0011334'
#  'C0008533' 'C0019112' 'C0005818' 'C0162423' 'C0009186' 'C0151436'
#  'C0035334' 'C0035333' 'C0242459' 'C0553723' 'C0001206' 'C0004245'
#  'C0151744' 'C0029442' 'C0085584' 'C0085580' 'C0003635' 'C0026848'
#  'C0019360' 'C0010054' 'C0033038' 'C0022408' 'C0026846' 'C0024110'
#  'C0039483' 'C0019163' 'C0024115' 'C0024117' 'C0035412' 'C0004623'
#  'C0031111' 'C0004626' 'C0027441' 'C0002726' 'C0009806' 'C0033581'
#  'C0006267' 'C0016436' 'C0040213' 'C0038436' 'C0039685' 'C0029191'
#  'C0027092' 'C0034194' 'C0022904' 'C0020473' 'C0005967' 'C0022572'
#  'C0022575' 'C0149925' 'C0014544' 'C0018790' 'C0152226' 'C0014541'
#  'C0014549' 'C0018799' 'C0008313' 'C0008312' 'C0022353' 'C0032285'
#  'C0013395' 'C0011630' 'C0031542' 'C0699885' 'C0024205' 'C0007097'
#  'C0008311' 'C0178879' 'C0836924' 'C0035344' 'C0036421' 'C0013473'
#  'C0017638' 'C0013080' 'C0030305' 'C0002103' 'C0032987' 'C0002453'
#  'C0033845' 'C0040034' 'C0155118' 'C0016807' 'C0032463' 'C0032460'
#  'C0007780' 'C0007787' 'C0007785' 'C0007789' 'C0040584' 'C0003850'
#  'C0041825' 'C0006118' 'C0029400' 'C0042961' 'C0023055' 'C0018939'
#  'C0020619' 'C0162283' 'C0009663' 'C0039520' 'C0042907' 'C0034902'
#  'C0040147' 'C0700594' 'C0013274' 'C0025637' 'C0008325' 'C0026987'
#  'C0028738' 'C0034888' 'C0016470' 'C0027059' 'C0020433' 'C0020437'
#  'C0036202' 'C0003175' 'C0026975' 'C0016977' 'C0678222' 'C0085786'
#  'C0005741' 'C0024121' 'C0005745' 'C0030848' 'C0023524' 'C1458155'
#  'C0037998' 'C0033246' 'C0006826' 'C0021845' 'C0009319' 'C0085762'
#  'C0001175' 'C0040921' 'C0020502' 'C0040435' 'C0018500' 'C0030491'
#  'C0008049' 'C0025202' 'C0022893' 'C0032533' 'C0006370' 'C0020295'
#  'C0036508' 'C0037052' 'C0007177' 'C0027709' 'C0034150' 'C0027707'
#  'C0002418' 'C0034155' 'C0021933' 'C0026650' 'C0024236' 'C0029134'
#  'C0020615' 'C0014868' 'C0023241' 'C0004153' 'C0004096' 'C0004095'
#  'C0024198' 'C0002390' 'C0011848' 'C0020540' 'C0030353' 'C0041952'
#  'C0035302' 'C0035304' 'C0017675' 'C0013537' 'C0035309' 'C0042384'
#  'C0015230' 'C0011615' 'C0035579' 'C0005779' 'C0026272' 'C0029456'
#  'C0029454' 'C0018801' 'C0018802' 'C0023067' 'C0038363' 'C0038362'
#  'C0030807' 'C0042373' 'C0152132' 'C0009782' 'C0023418' 'C0009326'
#  'C0009324' 'C0021400' 'C0025063' 'C1527336' 'C0008497' 'C0031046'
#  'C0015423' 'C0002736' 'C0009946' 'C0020542' 'C0034372' 'C0016034'
#  'C0042485' 'C0020545' 'C0699791' 'C0699790' 'C0149931' 'C0033117'
#  'C0018784' 'C0026946' 'C0023467' 'C0026948' 'C0019655' 'C0030756'
#  'C0033375' 'C0030578' 'C0013369' 'C0005424' 'C0034050' 'C0238454'
#  'C0033687' 'C0085652' 'C0040136' 'C0027822' 'C0001430' 'C0027947'
#  'C0032273' 'C0014118' 'C0156312' 'C0020490' 'C0022602' 'C0032371'
#  'C0011860' 'C0028077' 'C0035305' 'C0036439' 'C0039446' 'C0030354'
#  'C0014534' 'C0010692' 'C0021141' 'C0026603' 'C1442903' 'C0040028'
#  'C0003864' 'C0003868' 'C0003869' 'C0022735' 'C0341858' 'C0035436'
#  'C0032708' 'C0282488' 'C0178421' 'C0011616' 'C0018924' 'C0027121'
#  'C0008924' 'C0008925' 'C0155773' 'C0549473' 'C0008513' 'C0600327'
#  'C0022951' 'C0004114' 'C0011649' 'C0035222' 'C0015300' 'C0002940'
#  'C0019294' 'C0027022' 'C0025286' 'C0019348' 'C0010034' 'C0010036'
#  'C0019342' 'C0025322' 'C0042341' 'C0004238' 'C0019189' 'C0042345'
#  'C0079102' 'C0021359' 'C0011854' 'C0006444' 'C0014179' 'C0019917'
#  'C0003507' 'C0085207' 'C0025289' 'C0020514' 'C0020517' 'C0026393'
#  'C0020456' 'C0020626' 'C0027339' 'C0030583' 'C0042164' 'C0010417'
#  'C0015469' 'C0085681' 'C0019048' 'C0032290' 'C0018081' 'C0014733'
#  'C0034065' 'C0006849' 'C0007860' 'C0034063' 'C0006840' 'C0034069'
#  'C0036337' 'C0022081' 'C0020604' 'C0024225' 'C0221759' 'C0039614'
#  'C0029124' 'C0007462' 'C0030920' 'C0042769' 'C0027932' 'C0022679'
#  'C0032633' 'C0026780' 'C0028754' 'C0028840' 'C0878544' 'C0022104'
#  'C0151468' 'C0010674' 'C0149512' 'C0030326' 'C0149514' 'C0024894'
#  'C0022661' 'C0031048' 'C0012813' 'C0024899' 'C0038131' 'C0024299'
#  'C0017661' 'C0151514' 'C0001824' 'C0020676' 'C0021099' 'C0011603'
#  'C0001818' 'C0035460' 'C0026265' 'C0026267' 'C0038353' 'C0018818'
#  'C0003615' 'C0029463' 'C0042900' 'C0038358' 'C0018817' 'C0021390'
#  'C0039503' 'C0006144' 'C0006145' 'C0015645' 'C0152020' 'C0042267'
#  'C0031039' 'C0152025' 'C0031036' 'C0018418' 'C0221244' 'C0002994'
#  'C0001126' 'C0002622' 'C0014518' 'C0162678' 'C0020555' 'C0005695'
#  'C0020550' 'C0014390' 'C0017536' 'C0029882' 'C0001816' 'C0302592'
#  'C0270629' 'C0038220' 'C0042996']
# category_count:  0 ,  C0017152
# /root/anaconda3/lib/python3.9/site-packages/scipy/sparse/_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# category_count:  1 ,  C0027858
# category_count:  2 ,  C0041466
# category_count:  3 ,  C0032807
# category_count:  4 ,  C0033860
# category_count:  5 ,  C0259749
# category_count:  6 ,  C0349231
# category_count:  7 ,  C0027726
# category_count:  8 ,  C0024437
# category_count:  9 ,  C0024312
# [<4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 22140 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 866 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 20 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 416 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 7712 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 1500 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 550 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4150 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 3810 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4654 stored elements in Compressed Sparse Row format>]
# GHHHHHHHHHHHHHHHHH
# [array([0, 0, 0, ..., 0, 0, 0]), array([0, 0, 0, ..., 0, 0, 0]), array([0, 0, 0, ..., 0, 0, 0]), array([0, 0, 0, ..., 0, 0, 0]), array([0, 0, 0, ..., 0, 0, 0]), array([0, 0, 0, ..., 0, 0, 0]), array([0, 0, 0, ..., 0, 0, 0]), array([0, 0, 0, ..., 0, 0, 0]), array([0, 0, 0, ..., 0, 0, 0]), array([0, 0, 0, ..., 0, 0, 0])]

# %%
# data representation
adj_mats_orig = {
    (0, 0): [gene_adj, gene_adj.transpose(copy=True)],
    (0, 1): [gene_drug_adj],
    (1, 0): [drug_gene_adj],
    (1, 1): drug_drug_adj_list + [x.transpose(copy=True) for x in drug_drug_adj_list],
}


degrees = {
    0: [gene_degrees, gene_degrees],
    1: drug_degrees_list + drug_degrees_list,
}

# %%
# featureless (genes)
gene_feat = sp.identity(gene_max)
gene_nonzero_feat, gene_num_feat = gene_feat.shape
gene_feat = preprocessing.sparse_to_tuple(gene_feat.tocoo())

# features (drugs)
drug_feat = sp.identity(drug_max)
drug_nonzero_feat, drug_num_feat = drug_feat.shape
drug_feat = preprocessing.sparse_to_tuple(drug_feat.tocoo())

# data representation
num_feat = {
    0: gene_num_feat,
    1: drug_num_feat,
}
nonzero_feat = {
    0: gene_nonzero_feat,
    1: drug_nonzero_feat,
}
feat = {
    0: gene_feat,
    1: drug_feat,
}

edge_type2dim = {k: [adj.shape for adj in adjs] for k, adjs in adj_mats_orig.items()}
edge_type2decoder = {
    (0, 0): 'bilinear',
    (0, 1): 'bilinear',
    (1, 0): 'bilinear',
    (1, 1): 'dedicom',
}
print(adj_mats_orig)
edge_types = {k: len(v) for k, v in adj_mats_orig.items()}
print(edge_types)
num_edge_types = sum(edge_types.values())
print("Edge types:", "%d" % num_edge_types)
# Out:
# {(0, 0): [<38244x38244 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4998 stored elements in Compressed Sparse Row format>, <38244x38244 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4998 stored elements in Compressed Sparse Column format>], (0, 1): [<4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4654 stored elements in Compressed Sparse Row format>], (1, 0): [<4270x38244 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4998 stored elements in Compressed Sparse Column format>], (1, 1): [<4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 22140 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 866 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 20 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 416 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 7712 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 1500 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 550 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4150 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 3810 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4654 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 22140 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 866 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 20 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 416 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 7712 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 1500 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 550 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4150 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 3810 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4654 stored elements in Compressed Sparse Column format>]}
# {(0, 0): 2, (0, 1): 1, (1, 0): 1, (1, 1): 20}
# Edge types: 24

# %%
###########################################################
#
# Settings and placeholders
#
###########################################################

flags = tf.app.flags
FLAGS = flags.FLAGS
flags.DEFINE_integer('neg_sample_size', 1, 'Negative sample size.')
flags.DEFINE_float('learning_rate', 0.001, 'Initial learning rate.')
flags.DEFINE_integer('epochs', 50, 'Number of epochs to train.')
flags.DEFINE_integer('hidden1', 64, 'Number of units in hidden layer 1.')
flags.DEFINE_integer('hidden2', 32, 'Number of units in hidden layer 2.')
flags.DEFINE_float('weight_decay', 0, 'Weight for L2 loss on embedding matrix.')
flags.DEFINE_float('dropout', 0.1, 'Dropout rate (1 - keep probability).')
flags.DEFINE_float('max_margin', 0.1, 'Max margin parameter in hinge loss')
flags.DEFINE_integer('batch_size', 512, 'minibatch size.')
flags.DEFINE_boolean('bias', True, 'Bias term.')
flags.DEFINE_string("f", "", "kernel")
# Important -- Do not evaluate/print validation performance every iteration as it can take
# substantial amount of time
PRINT_PROGRESS_EVERY = 150

print("Defining placeholders")
placeholders = construct_placeholders(edge_types)
print(placeholders)
# Out:
# Defining placeholders
# {'batch': <tf.Tensor 'batch:0' shape=<unknown> dtype=int32>, 'batch_edge_type_idx': <tf.Tensor 'batch_edge_type_idx:0' shape=() dtype=int32>, 'batch_row_edge_type': <tf.Tensor 'batch_row_edge_type:0' shape=() dtype=int32>, 'batch_col_edge_type': <tf.Tensor 'batch_col_edge_type:0' shape=() dtype=int32>, 'degrees': <tf.Tensor 'Placeholder:0' shape=<unknown> dtype=int32>, 'dropout': <tf.Tensor 'PlaceholderWithDefault:0' shape=() dtype=float32>, 'adj_mats_0,0,0': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f9b49b20>, 'adj_mats_0,0,1': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f9b490a0>, 'adj_mats_0,1,0': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f9bb0490>, 'adj_mats_1,0,0': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f9bb0520>, 'adj_mats_1,1,0': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f9bb77f0>, 'adj_mats_1,1,1': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f9bb7370>, 'adj_mats_1,1,2': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f88641f0>, 'adj_mats_1,1,3': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8864490>, 'adj_mats_1,1,4': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8864790>, 'adj_mats_1,1,5': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8864a90>, 'adj_mats_1,1,6': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8864d90>, 'adj_mats_1,1,7': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8879100>, 'adj_mats_1,1,8': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f88793d0>, 'adj_mats_1,1,9': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f88796d0>, 'adj_mats_1,1,10': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f88799d0>, 'adj_mats_1,1,11': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8879cd0>, 'adj_mats_1,1,12': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8879fd0>, 'adj_mats_1,1,13': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8a0c0d0>, 'adj_mats_1,1,14': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8a0c610>, 'adj_mats_1,1,15': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8a0c910>, 'adj_mats_1,1,16': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8a0cc10>, 'adj_mats_1,1,17': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8a0cf10>, 'adj_mats_1,1,18': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8899040>, 'adj_mats_1,1,19': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8899550>, 'feat_0': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f8899910>, 'feat_1': <tensorflow.python.framework.sparse_tensor.SparseTensor object at 0x7f95f88cc0a0>}

# %%
###########################################################
#
# Create minibatch iterator, model and optimizer
#
###########################################################

# I changed decagon/deep/minibatch code (def mask_test_edges)


print("Create minibatch iterator")
print("adj_mats_orig")
print(adj_mats_orig)
print("feat")
print(feat)
print("edge_types")
print("FLAGS.batch_size")
print(FLAGS.batch_size)
print("val_test_size")
print(val_test_size)

minibatch = EdgeMinibatchIterator(
    adj_mats=adj_mats_orig,
    feat=feat,
    edge_types=edge_types,
    batch_size=FLAGS.batch_size,
    val_test_size=val_test_size
)

print("Create model")
model = DecagonModel(
    placeholders=placeholders,
    num_feat=num_feat,
    nonzero_feat=nonzero_feat,
    edge_types=edge_types,
    decoders=edge_type2decoder,
)

print("Create optimizer")
with tf.name_scope('optimizer'):
    opt = DecagonOptimizer(
        embeddings=model.embeddings,
        latent_inters=model.latent_inters,
        latent_varies=model.latent_varies,
        degrees=degrees,
        edge_types=edge_types,
        edge_type2dim=edge_type2dim,
        placeholders=placeholders,
        batch_size=FLAGS.batch_size,
        margin=FLAGS.max_margin
    )

print("Initialize session")
sess = tf.Session()
sess.run(tf.global_variables_initializer())
feed_dict = {}
# Out:
# Create minibatch iterator
# Create minibatch iterator
# adj_mats_orig
# {(0, 0): [<38244x38244 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4998 stored elements in Compressed Sparse Row format>, <38244x38244 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4998 stored elements in Compressed Sparse Column format>], (0, 1): [<4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4654 stored elements in Compressed Sparse Row format>], (1, 0): [<4270x38244 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4998 stored elements in Compressed Sparse Column format>], (1, 1): [<4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 22140 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 866 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 20 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 416 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 7712 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 1500 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 550 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4150 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 3810 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4654 stored elements in Compressed Sparse Row format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 22140 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 866 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 20 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 416 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 7712 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 1500 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 550 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4150 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 3810 stored elements in Compressed Sparse Column format>, <4270x4270 sparse matrix of type '<class 'numpy.int8'>'
# 	with 4654 stored elements in Compressed Sparse Column format>]}
# feat
# {0: (array([[        0,         0],
#        [        1,         1],
#        [        2,         2],
#        ...,
#        [110255166, 110255166],
#        [110255167, 110255167],
#        [110255168, 110255168]], dtype=int32), array([1., 1., 1., ..., 1., 1., 1.]), (110255169, 110255169)), 1: (array([[        0,         0],
#        [        1,         1],
#        [        2,         2],
#        ...,
#        [154677974, 154677974],
#        [154677975, 154677975],
#        [154677976, 154677976]], dtype=int32), array([1., 1., 1., ..., 1., 1., 1.]), (154677977, 154677977))}
# edge_types
# FLAGS.batch_size
# 512
# val_test_size
# 0.05
# i, j:  0 0
# k:  0
# Minibatch edge type: (0, 0, 0)
# Constructing test edges= 0000/0249
# Constructing val edges= 0000/0249
# Train edges= 4500
# Val edges= 0249
# Test edges= 0249
# k:  1
# Minibatch edge type: (0, 0, 1)
# Constructing test edges= 0000/0249
# Constructing val edges= 0000/0249
# Train edges= 4500
# Val edges= 0249
# Test edges= 0249
# i, j:  0 1
# k:  0
# Minibatch edge type: (0, 1, 0)
# Constructing test edges= 0000/0232
# Constructing val edges= 0000/0232
# Train edges= 4190
# Val edges= 0232
# Test edges= 0232
# i, j:  1 0
# k:  0
# Minibatch edge type: (1, 0, 0)
# Constructing test edges= 0000/0249
# Constructing val edges= 0000/0249
# Train edges= 4500
# Val edges= 0249
# Test edges= 0249
# i, j:  1 1
# k:  0
# Minibatch edge type: (1, 1, 0)
# Constructing test edges= 0000/1107
# /root/decagon/decagon/deep/minibatch.py:69: RuntimeWarning: divide by zero encountered in power
#   rowdegree_mat_inv = sp.diags(np.nan_to_num(np.power(rowsum, -0.5)).flatten())
# /root/decagon/decagon/deep/minibatch.py:70: RuntimeWarning: divide by zero encountered in power
#   coldegree_mat_inv = sp.diags(np.nan_to_num(np.power(colsum, -0.5)).flatten())
# Constructing test edges= 1000/1107
# Constructing val edges= 0000/1107
# Constructing val edges= 1000/1107
# Train edges= 19926
# Val edges= 1107
# Test edges= 1107
# k:  1
# Minibatch edge type: (1, 1, 1)
# Constructing test edges= 0000/0043
# Constructing val edges= 0000/0043
# Train edges= 0780
# Val edges= 0043
# Test edges= 0043
# k:  2
# Minibatch edge type: (1, 1, 2)
# Constructing test edges= 0000/0010
# Constructing val edges= 0000/0010
# Train edges= 0000
# Val edges= 0010
# Test edges= 0010
# k:  3
# Minibatch edge type: (1, 1, 3)
# Constructing test edges= 0000/0020
# Constructing val edges= 0000/0020
# Train edges= 0376
# Val edges= 0020
# Test edges= 0020
# k:  4
# Minibatch edge type: (1, 1, 4)
# Constructing test edges= 0000/0385
# Constructing val edges= 0000/0385
# Train edges= 6942
# Val edges= 0385
# Test edges= 0385
# k:  5
# Minibatch edge type: (1, 1, 5)
# Constructing test edges= 0000/0075
# Constructing val edges= 0000/0075
# Train edges= 1350
# Val edges= 0075
# Test edges= 0075
# k:  6
# Minibatch edge type: (1, 1, 6)
# Constructing test edges= 0000/0027
# Constructing val edges= 0000/0027
# Train edges= 0496
# Val edges= 0027
# Test edges= 0027
# k:  7
# Minibatch edge type: (1, 1, 7)
# Constructing test edges= 0000/0207
# Constructing val edges= 0000/0207
# Train edges= 3736
# Val edges= 0207
# Test edges= 0207
# k:  8
# Minibatch edge type: (1, 1, 8)
# Constructing test edges= 0000/0190
# Constructing val edges= 0000/0190
# Train edges= 3430
# Val edges= 0190
# Test edges= 0190
# k:  9
# Minibatch edge type: (1, 1, 9)
# Constructing test edges= 0000/0232
# Constructing val edges= 0000/0232
# Train edges= 4190
# Val edges= 0232
# Test edges= 0232
# k:  10
# Minibatch edge type: (1, 1, 10)
# Constructing test edges= 0000/1107
# Constructing test edges= 1000/1107
# Constructing val edges= 0000/1107
# Constructing val edges= 1000/1107
# Train edges= 19926
# Val edges= 1107
# Test edges= 1107
# k:  11
# Minibatch edge type: (1, 1, 11)
# Constructing test edges= 0000/0043
# Constructing val edges= 0000/0043
# Train edges= 0780
# Val edges= 0043
# Test edges= 0043
# k:  12
# Minibatch edge type: (1, 1, 12)
# Constructing test edges= 0000/0010
# Constructing val edges= 0000/0010
# Train edges= 0000
# Val edges= 0010
# Test edges= 0010
# k:  13
# Minibatch edge type: (1, 1, 13)
# Constructing test edges= 0000/0020
# Constructing val edges= 0000/0020
# Train edges= 0376
# Val edges= 0020
# Test edges= 0020
# k:  14
# Minibatch edge type: (1, 1, 14)
# Constructing test edges= 0000/0385
# Constructing val edges= 0000/0385
# Train edges= 6942
# Val edges= 0385
# Test edges= 0385
# k:  15
# Minibatch edge type: (1, 1, 15)
# Constructing test edges= 0000/0075
# Constructing val edges= 0000/0075
# Train edges= 1350
# Val edges= 0075
# Test edges= 0075
# k:  16
# Minibatch edge type: (1, 1, 16)
# Constructing test edges= 0000/0027
# Constructing val edges= 0000/0027
# Train edges= 0496
# Val edges= 0027
# Test edges= 0027
# k:  17
# Minibatch edge type: (1, 1, 17)
# Constructing test edges= 0000/0207
# Constructing val edges= 0000/0207
# Train edges= 3736
# Val edges= 0207
# Test edges= 0207
# k:  18
# Minibatch edge type: (1, 1, 18)
# Constructing test edges= 0000/0190
# Constructing val edges= 0000/0190
# Train edges= 3430
# Val edges= 0190
# Test edges= 0190
# k:  19
# Minibatch edge type: (1, 1, 19)
# Constructing test edges= 0000/0232
# Constructing val edges= 0000/0232
# Train edges= 4190
# Val edges= 0232
# Test edges= 0232
# Create model
# WARNING:tensorflow:From /root/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead
# WARNING:tensorflow:From /root/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Create optimizer
# WARNING:tensorflow:tf.op_scope(values, name, default_name) is deprecated, use tf.name_scope(name, default_name, values)
# WARNING:tensorflow:tf.op_scope(values, name, default_name) is deprecated, use tf.name_scope(name, default_name, values)
# /root/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("optimizer/gradients/concat_5:0", shape=(None,), dtype=int32), values=Tensor("optimizer/gradients/decagonmodel/AddN_2_grad/tuple/control_dependency:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("optimizer/gradients/optimizer/concat_1_grad/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /root/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("optimizer/gradients/concat_5:0", shape=(None,), dtype=int32), values=Tensor("optimizer/gradients/decagonmodel/AddN_2_grad/tuple/control_dependency_1:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("optimizer/gradients/optimizer/concat_1_grad/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /root/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("optimizer/gradients/concat_7:0", shape=(None,), dtype=int32), values=Tensor("optimizer/gradients/decagonmodel/AddN_3_grad/tuple/control_dependency:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("optimizer/gradients/optimizer/concat_1_grad/Shape_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /root/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("optimizer/gradients/concat_7:0", shape=(None,), dtype=int32), values=Tensor("optimizer/gradients/decagonmodel/AddN_3_grad/tuple/control_dependency_1:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("optimizer/gradients/optimizer/concat_1_grad/Shape_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /root/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("optimizer/gradients_1/concat_5:0", shape=(None,), dtype=int32), values=Tensor("optimizer/gradients_1/decagonmodel/AddN_2_grad/tuple/control_dependency:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("optimizer/gradients_1/optimizer/concat_1_grad/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /root/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("optimizer/gradients_1/concat_5:0", shape=(None,), dtype=int32), values=Tensor("optimizer/gradients_1/decagonmodel/AddN_2_grad/tuple/control_dependency_1:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("optimizer/gradients_1/optimizer/concat_1_grad/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /root/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("optimizer/gradients_1/concat_7:0", shape=(None,), dtype=int32), values=Tensor("optimizer/gradients_1/decagonmodel/AddN_3_grad/tuple/control_dependency:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("optimizer/gradients_1/optimizer/concat_1_grad/Shape_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /root/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("optimizer/gradients_1/concat_7:0", shape=(None,), dtype=int32), values=Tensor("optimizer/gradients_1/decagonmodel/AddN_3_grad/tuple/control_dependency_1:0", shape=(None, 32), dtype=float32), dense_shape=Tensor("optimizer/gradients_1/optimizer/concat_1_grad/Shape_1:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# Initialize session
# 2022-08-30 06:15:03.735886: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-30 06:15:03.742516: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# 2022-08-30 06:16:58.397652: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (mklcpu) ran out of memory trying to allocate 36.88GiB (rounded to 39597562112)requested by op decagonmodel/graphconvolutionsparsemulti_4_vars/weights_4/Adam/Initializer/zeros
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-08-30 06:16:58.397782: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for mklcpu
# 2022-08-30 06:16:58.397817: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397837: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397852: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397866: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397881: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397895: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397910: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397924: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397938: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397952: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397966: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397980: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.397994: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.398011: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 1, Chunks in use: 0. 2.00MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.398025: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.398039: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.398053: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.398067: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.398081: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.398100: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:16:58.398127: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 8, Chunks in use: 5. 251.81GiB allocated for chunks. 184.39GiB in use in bin. 184.39GiB client-requested in use in bin.
# 2022-08-30 06:16:58.398151: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 36.88GiB was 256.00MiB, Chunk State:
# 2022-08-30 06:16:58.398179: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 13.18GiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 36.88GiB | Requested Size: 36.88GiB | in_use: 1 | bin_num: -1
# 2022-08-30 06:16:58.398198: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 27.12GiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 36.88GiB | Requested Size: 36.88GiB | in_use: 1 | bin_num: -1
# 2022-08-30 06:16:58.398216: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 27.12GiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 36.88GiB | Requested Size: 36.88GiB | in_use: 1 | bin_num: -1
# 2022-08-30 06:16:58.398228: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 2097152
# 2022-08-30 06:16:58.398243: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 55e114a06340 of size 2097152 next 18446744073709551615
# 2022-08-30 06:16:58.398256: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 132940783616
# 2022-08-30 06:16:58.398269: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f54201c5040 of size 39597562112 next 6
# 2022-08-30 06:16:58.398285: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f5d584f2940 of size 39597562112 next 7
# 2022-08-30 06:16:58.398297: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f6690820240 of size 39597562112 next 8
# 2022-08-30 06:16:58.398309: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f6fc8b4db40 of size 14148097280 next 18446744073709551615
# 2022-08-30 06:16:58.398321: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 68719476736
# 2022-08-30 06:16:58.398333: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f7393ffd040 of size 39597562112 next 4
# 2022-08-30 06:16:58.398344: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f7ccc32a940 of size 29121914624 next 18446744073709551615
# 2022-08-30 06:16:58.398356: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 68719476736
# 2022-08-30 06:16:58.398368: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f8413fff040 of size 39597562112 next 2
# 2022-08-30 06:16:58.398379: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f8d4c32c940 of size 29121914624 next 18446744073709551615
# 2022-08-30 06:16:58.398391: I tensorflow/core/common_runtime/bfc_allocator.cc:1071]      Summary of in-use Chunks by size:
# 2022-08-30 06:16:58.398407: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 5 Chunks of size 39597562112 totalling 184.39GiB
# 2022-08-30 06:16:58.398421: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 184.39GiB
# 2022-08-30 06:16:58.398434: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 270381834240 memory_limit_: 270381834240 available bytes: 0 curr_region_allocation_bytes_: 274877906944
# 2022-08-30 06:16:58.398454: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                    270381834240
# InUse:                    197987810560
# MaxInUse:                 197987810560
# NumAllocs:                          34
# MaxAllocSize:              39597562112
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-08-30 06:16:58.398471: W tensorflow/core/common_runtime/bfc_allocator.cc:474] ********************************************_____***************__________****************__________
# 2022-08-30 06:16:58.398520: W tensorflow/core/framework/op_kernel.cc:1722] OP_REQUIRES failed at constant_op.cc:81 : INVALID_ARGUMENT: Cannot parse tensor from tensor_proto.
# 2022-08-30 06:18:50.941326: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (mklcpu) ran out of memory trying to allocate 36.88GiB (rounded to 39597562112)requested by op decagonmodel/graphconvolutionsparsemulti_4_vars/random_uniform_12/RandomUniform
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-08-30 06:18:50.942211: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for mklcpu
# 2022-08-30 06:18:50.942372: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942393: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942408: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942425: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942447: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 7, Chunks in use: 7. 28.0KiB allocated for chunks. 28.0KiB in use in bin. 28.0KiB client-requested in use in bin.
# 2022-08-30 06:18:50.942466: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 25, Chunks in use: 25. 200.0KiB allocated for chunks. 200.0KiB in use in bin. 200.0KiB client-requested in use in bin.
# 2022-08-30 06:18:50.942483: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942498: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942513: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942528: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942543: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942557: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942573: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 1, Chunks in use: 0. 1.78MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942588: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942602: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942616: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942631: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942646: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942660: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942679: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:18:50.942699: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 10, Chunks in use: 7. 251.81GiB allocated for chunks. 215.78GiB in use in bin. 215.78GiB client-requested in use in bin.
# 2022-08-30 06:18:50.942716: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 36.88GiB was 256.00MiB, Chunk State:
# 2022-08-30 06:18:50.942849: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 855.06MiB | Requested Size: 4.0KiB | in_use: 0 | bin_num: 20, prev:   Size: 36.88GiB | Requested Size: 36.88GiB | in_use: 1 | bin_num: -1
# 2022-08-30 06:18:50.942877: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 855.06MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 36.88GiB | Requested Size: 36.88GiB | in_use: 1 | bin_num: -1
# 2022-08-30 06:18:50.942896: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 34.36GiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 26.29GiB | Requested Size: 26.29GiB | in_use: 1 | bin_num: -1
# 2022-08-30 06:18:50.942909: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 2097152
# 2022-08-30 06:18:50.942928: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a06340 of size 4096 next 12
# 2022-08-30 06:18:50.942941: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a07340 of size 4096 next 13
# 2022-08-30 06:18:50.942953: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a08340 of size 8192 next 10
# 2022-08-30 06:18:50.942965: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a0a340 of size 8192 next 4
# 2022-08-30 06:18:50.942977: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a0c340 of size 8192 next 7
# 2022-08-30 06:18:50.942989: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a0e340 of size 8192 next 8
# 2022-08-30 06:18:50.943001: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a10340 of size 8192 next 6
# 2022-08-30 06:18:50.943013: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a12340 of size 8192 next 14
# 2022-08-30 06:18:50.943024: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a14340 of size 8192 next 15
# 2022-08-30 06:18:50.943036: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a16340 of size 8192 next 16
# 2022-08-30 06:18:50.943047: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a18340 of size 8192 next 17
# 2022-08-30 06:18:50.943058: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a1a340 of size 8192 next 18
# 2022-08-30 06:18:50.943070: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a1c340 of size 8192 next 19
# 2022-08-30 06:18:50.943081: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a1e340 of size 8192 next 20
# 2022-08-30 06:18:50.943092: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a20340 of size 8192 next 21
# 2022-08-30 06:18:50.943104: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a22340 of size 8192 next 22
# 2022-08-30 06:18:50.943115: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a24340 of size 8192 next 23
# 2022-08-30 06:18:50.943126: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a26340 of size 8192 next 24
# 2022-08-30 06:18:50.943137: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a28340 of size 8192 next 25
# 2022-08-30 06:18:50.943148: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a2a340 of size 8192 next 26
# 2022-08-30 06:18:50.943180: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a2c340 of size 8192 next 27
# 2022-08-30 06:18:50.943186: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a2e340 of size 8192 next 28
# 2022-08-30 06:18:50.943192: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a30340 of size 8192 next 29
# 2022-08-30 06:18:50.943200: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a32340 of size 8192 next 30
# 2022-08-30 06:18:50.943207: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a34340 of size 8192 next 31
# 2022-08-30 06:18:50.943213: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a36340 of size 8192 next 32
# 2022-08-30 06:18:50.943219: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a38340 of size 8192 next 33
# 2022-08-30 06:18:50.943227: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a3a340 of size 4096 next 34
# 2022-08-30 06:18:50.943234: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a3b340 of size 4096 next 35
# 2022-08-30 06:18:50.943240: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a3c340 of size 4096 next 36
# 2022-08-30 06:18:50.943246: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a3d340 of size 4096 next 37
# 2022-08-30 06:18:50.943253: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a3e340 of size 4096 next 38
# 2022-08-30 06:18:50.943261: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 55e114a3f340 of size 1863680 next 18446744073709551615
# 2022-08-30 06:18:50.943269: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 132940783616
# 2022-08-30 06:18:50.943276: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f54201c5040 of size 28225323264 next 40
# 2022-08-30 06:18:50.943282: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f5ab2789140 of size 39597562112 next 41
# 2022-08-30 06:18:50.943290: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f63eaab6a40 of size 28225323264 next 42
# 2022-08-30 06:18:50.943296: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f6a7d07ab40 of size 36892574976 next 18446744073709551615
# 2022-08-30 06:18:50.943302: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 68719476736
# 2022-08-30 06:18:50.943308: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f7393ffd040 of size 28225323264 next 11
# 2022-08-30 06:18:50.943314: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f7a265c1140 of size 39597562112 next 9
# 2022-08-30 06:18:50.943320: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f835e8eea40 of size 896591360 next 18446744073709551615
# 2022-08-30 06:18:50.943327: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 68719476736
# 2022-08-30 06:18:50.943333: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f8413fff040 of size 28225323264 next 2
# 2022-08-30 06:18:50.943339: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f8aa65c3140 of size 39597562112 next 39
# 2022-08-30 06:18:50.943345: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f93de8f0a40 of size 896591360 next 18446744073709551615
# 2022-08-30 06:18:50.943351: I tensorflow/core/common_runtime/bfc_allocator.cc:1071]      Summary of in-use Chunks by size:
# 2022-08-30 06:18:50.943360: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 7 Chunks of size 4096 totalling 28.0KiB
# 2022-08-30 06:18:50.943367: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 25 Chunks of size 8192 totalling 200.0KiB
# 2022-08-30 06:18:50.943375: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 28225323264 totalling 105.15GiB
# 2022-08-30 06:18:50.943382: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 3 Chunks of size 39597562112 totalling 110.63GiB
# 2022-08-30 06:18:50.943390: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 215.78GiB
# 2022-08-30 06:18:50.943397: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 270381834240 memory_limit_: 270381834240 available bytes: 0 curr_region_allocation_bytes_: 274877906944
# 2022-08-30 06:18:50.944198: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                    270381834240
# InUse:                    231694212864
# MaxInUse:                 231694212864
# NumAllocs:                          83
# MaxAllocSize:              39597562112
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-08-30 06:18:50.944216: W tensorflow/core/common_runtime/bfc_allocator.cc:474] ************************************_____________***************************************************
# 2022-08-30 06:18:50.945493: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at random_op.cc:74 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[154677977,64] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# 2022-08-30 06:19:00.944510: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (mklcpu) ran out of memory trying to allocate 36.88GiB (rounded to 39597562112)requested by op decagonmodel/graphconvolutionsparsemulti_4_vars/random_uniform_13/RandomUniform
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-08-30 06:19:00.944580: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for mklcpu
# 2022-08-30 06:19:00.944601: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944618: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944634: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944648: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944667: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 7, Chunks in use: 7. 28.0KiB allocated for chunks. 28.0KiB in use in bin. 28.0KiB client-requested in use in bin.
# 2022-08-30 06:19:00.944686: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 25, Chunks in use: 25. 200.0KiB allocated for chunks. 200.0KiB in use in bin. 200.0KiB client-requested in use in bin.
# 2022-08-30 06:19:00.944701: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944715: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944729: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944743: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944758: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944772: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944787: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 1, Chunks in use: 0. 1.78MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944802: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944816: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944830: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944845: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944859: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944873: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944887: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-08-30 06:19:00.944905: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 10, Chunks in use: 7. 251.81GiB allocated for chunks. 215.78GiB in use in bin. 215.78GiB client-requested in use in bin.
# 2022-08-30 06:19:00.944923: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 36.88GiB was 256.00MiB, Chunk State:
# 2022-08-30 06:19:00.944947: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 855.06MiB | Requested Size: 4.0KiB | in_use: 0 | bin_num: 20, prev:   Size: 36.88GiB | Requested Size: 36.88GiB | in_use: 1 | bin_num: -1
# 2022-08-30 06:19:00.944966: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 855.06MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 36.88GiB | Requested Size: 36.88GiB | in_use: 1 | bin_num: -1
# 2022-08-30 06:19:00.944983: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 34.36GiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 26.29GiB | Requested Size: 26.29GiB | in_use: 1 | bin_num: -1
# 2022-08-30 06:19:00.944996: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 2097152
# 2022-08-30 06:19:00.945011: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a06340 of size 4096 next 12
# 2022-08-30 06:19:00.945024: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a07340 of size 4096 next 13
# 2022-08-30 06:19:00.945037: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a08340 of size 8192 next 10
# 2022-08-30 06:19:00.945049: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a0a340 of size 8192 next 4
# 2022-08-30 06:19:00.945061: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a0c340 of size 8192 next 7
# 2022-08-30 06:19:00.945073: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a0e340 of size 8192 next 8
# 2022-08-30 06:19:00.945085: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a10340 of size 8192 next 6
# 2022-08-30 06:19:00.945097: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a12340 of size 8192 next 14
# 2022-08-30 06:19:00.945108: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a14340 of size 8192 next 15
# 2022-08-30 06:19:00.945120: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a16340 of size 8192 next 16
# 2022-08-30 06:19:00.945131: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a18340 of size 8192 next 17
# 2022-08-30 06:19:00.945142: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a1a340 of size 8192 next 18
# 2022-08-30 06:19:00.945154: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a1c340 of size 8192 next 19
# 2022-08-30 06:19:00.945165: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a1e340 of size 8192 next 20
# 2022-08-30 06:19:00.945177: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a20340 of size 8192 next 21
# 2022-08-30 06:19:00.945188: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a22340 of size 8192 next 22
# 2022-08-30 06:19:00.945199: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a24340 of size 8192 next 23
# 2022-08-30 06:19:00.945211: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a26340 of size 8192 next 24
# 2022-08-30 06:19:00.945222: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a28340 of size 8192 next 25
# 2022-08-30 06:19:00.945234: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a2a340 of size 8192 next 26
# 2022-08-30 06:19:00.945246: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a2c340 of size 8192 next 27
# 2022-08-30 06:19:00.945257: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a2e340 of size 8192 next 28
# 2022-08-30 06:19:00.945269: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a30340 of size 8192 next 29
# 2022-08-30 06:19:00.945281: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a32340 of size 8192 next 30
# 2022-08-30 06:19:00.945294: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a34340 of size 8192 next 31
# 2022-08-30 06:19:00.945305: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a36340 of size 8192 next 32
# 2022-08-30 06:19:00.945317: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a38340 of size 8192 next 33
# 2022-08-30 06:19:00.945328: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a3a340 of size 4096 next 34
# 2022-08-30 06:19:00.945340: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a3b340 of size 4096 next 35
# 2022-08-30 06:19:00.945351: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a3c340 of size 4096 next 36
# 2022-08-30 06:19:00.945362: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a3d340 of size 4096 next 37
# 2022-08-30 06:19:00.945373: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 55e114a3e340 of size 4096 next 38
# 2022-08-30 06:19:00.945385: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 55e114a3f340 of size 1863680 next 18446744073709551615
# 2022-08-30 06:19:00.945397: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 132940783616
# 2022-08-30 06:19:00.945410: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f54201c5040 of size 28225323264 next 40
# 2022-08-30 06:19:00.945422: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f5ab2789140 of size 39597562112 next 41
# 2022-08-30 06:19:00.945434: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f63eaab6a40 of size 28225323264 next 42
# 2022-08-30 06:19:00.945445: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f6a7d07ab40 of size 36892574976 next 18446744073709551615
# 2022-08-30 06:19:00.945457: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 68719476736
# 2022-08-30 06:19:00.945469: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f7393ffd040 of size 28225323264 next 11
# 2022-08-30 06:19:00.945480: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f7a265c1140 of size 39597562112 next 9
# ...
# 2022-08-30 06:21:50.971731: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f7a265c1140 of size 39597562112 next 9
# 2022-08-30 06:21:50.971744: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f835e8eea40 of size 896591360 next 18446744073709551615
# 2022-08-30 06:21:50.971758: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 68719476736
# 2022-08-30 06:21:50.971777: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f8413fff040 of size 28225323264 next 2
# 2022-08-30 06:21:50.971797: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f8aa65c3140 of size 39597562112 next 39
# 2022-08-30 06:21:50.971817: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f93de8f0a40 of size 896591360 next 18446744073709551615
# 2022-08-30 06:21:50.971836: I tensorflow/core/common_runtime/bfc_allocator.cc:1071]      Summary of in-use Chunks by size:
# 2022-08-30 06:21:50.971861: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 7 Chunks of size 4096 totalling 28.0KiB
# 2022-08-30 06:21:50.971884: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 25 Chunks of size 8192 totalling 200.0KiB
# 2022-08-30 06:21:50.971900: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 28225323264 totalling 105.15GiB
# 2022-08-30 06:21:50.971914: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 3 Chunks of size 39597562112 totalling 110.63GiB
# 2022-08-30 06:21:50.971937: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 215.78GiB
# 2022-08-30 06:21:50.971953: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 270381834240 memory_limit_: 270381834240 available bytes: 0 curr_region_allocation_bytes_: 274877906944
# 2022-08-30 06:21:50.971971: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                    270381834240
# InUse:                    231694212864
# MaxInUse:                 231694212864
# NumAllocs:                          83
# MaxAllocSize:              39597562112
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-08-30 06:21:50.971989: W tensorflow/core/common_runtime/bfc_allocator.cc:474] ************************************_____________***************************************************
# 2022-08-30 06:21:50.972041: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at random_op.cc:74 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[154677977,64] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/client/session.py:1377, in BaseSession._do_call(self, fn, *args)
#    1376 try:
# -> 1377   return fn(*args)
#    1378 except errors.OpError as e:
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/client/session.py:1360, in BaseSession._do_run.<locals>._run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1359 self._extend_graph()
# -> 1360 return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1361                                 target_list, run_metadata)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/client/session.py:1453, in BaseSession._call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1451 def _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list,
#    1452                         run_metadata):
# -> 1453   return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1454                                           fetch_list, target_list,
#    1455                                           run_metadata)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[154677977,64] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# 	 [[{{node decagonmodel/graphconvolutionsparsemulti_4_vars/random_uniform_12/RandomUniform}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [18], in <cell line: 56>()
#      54 print("Initialize session")
#      55 sess = tf.Session()
# ---> 56 sess.run(tf.global_variables_initializer())
#      57 feed_dict = {}
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/client/session.py:967, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     964 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     966 try:
# --> 967   result = self._run(None, fetches, feed_dict, options_ptr,
#     968                      run_metadata_ptr)
#     969   if run_metadata:
#     970     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/client/session.py:1190, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1187 # We only want to really perform the run if fetches or targets are provided,
#    1188 # or if the call is a partial run that specifies feeds.
#    1189 if final_fetches or final_targets or (handle and feed_dict_tensor):
# -> 1190   results = self._do_run(handle, final_targets, final_fetches,
#    1191                          feed_dict_tensor, options, run_metadata)
#    1192 else:
#    1193   results = []
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/client/session.py:1370, in BaseSession._do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1367   return self._call_tf_sessionprun(handle, feed_dict, fetch_list)
#    1369 if handle is None:
# -> 1370   return self._do_call(_run_fn, feeds, fetches, targets, options,
#    1371                        run_metadata)
#    1372 else:
#    1373   return self._do_call(_prun_fn, handle, feeds, fetches)
#
# File ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/client/session.py:1396, in BaseSession._do_call(self, fn, *args)
#    1391 if 'only supports NHWC tensor format' in message:
#    1392   message += ('\nA possible workaround: Try disabling Grappler optimizer'
#    1393               '\nby modifying the config for creating the session eg.'
#    1394               '\nsession_config.graph_options.rewrite_options.'
#    1395               'disable_meta_optimizer = True')
# -> 1396 raise type(e)(node_def, op, message)
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'decagonmodel/graphconvolutionsparsemulti_4_vars/random_uniform_12/RandomUniform' defined at (most recent call last):
#     File "/root/anaconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/root/anaconda3/lib/python3.9/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/root/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 16, in <module>
#       app.launch_new_instance()
#     File "/root/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#       app.start()
#     File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 677, in start
#       self.io_loop.start()
#     File "/root/anaconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "/root/anaconda3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#       self._run_once()
#     File "/root/anaconda3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#       handle._run()
#     File "/root/anaconda3/lib/python3.9/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_queue
#       await self.process_one()
#     File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 460, in process_one
#       await dispatch(*args)
#     File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 367, in dispatch_shell
#       await result
#     File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 662, in execute_request
#       reply_content = await reply_content
#     File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 360, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2881, in run_cell
#       result = self._run_cell(
#     File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2936, in _run_cell
#       return runner(coro)
#     File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3135, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_19239/2623286357.py", line 32, in <cell line: 32>
#       model = DecagonModel(
#     File "/root/decagon/decagon/deep/model.py", line 62, in __init__
#       self.build()
#     File "/root/decagon/decagon/deep/model.py", line 36, in build
#       self._build()
#     File "/root/decagon/decagon/deep/model.py", line 67, in _build
#       self.hidden1[i].append(GraphConvolutionSparseMulti(
#     File "/root/decagon/decagon/deep/layers.py", line 82, in __init__
#       self.vars['weights_%d' % k] = inits.weight_variable_glorot(
#     File "/root/decagon/decagon/deep/inits.py", line 10, in weight_variable_glorot
#       initial = tf.random_uniform([input_dim, output_dim], minval=-init_range,
# Node: 'decagonmodel/graphconvolutionsparsemulti_4_vars/random_uniform_12/RandomUniform'
# OOM when allocating tensor with shape[154677977,64] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator mklcpu
# 	 [[{{node decagonmodel/graphconvolutionsparsemulti_4_vars/random_uniform_12/RandomUniform}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# Original stack trace for 'decagonmodel/graphconvolutionsparsemulti_4_vars/random_uniform_12/RandomUniform':
#   File "/root/anaconda3/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/root/anaconda3/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/root/anaconda3/lib/python3.9/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/root/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "/root/anaconda3/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/root/anaconda3/lib/python3.9/asyncio/base_events.py", line 601, in run_forever
#     self._run_once()
#   File "/root/anaconda3/lib/python3.9/asyncio/base_events.py", line 1905, in _run_once
#     handle._run()
#   File "/root/anaconda3/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_queue
#     await self.process_one()
#   File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 460, in process_one
#     await dispatch(*args)
#   File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 367, in dispatch_shell
#     await result
#   File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 662, in execute_request
#     reply_content = await reply_content
#   File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 360, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/root/anaconda3/lib/python3.9/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2881, in run_cell
#     result = self._run_cell(
#   File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2936, in _run_cell
#     return runner(coro)
#   File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3135, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3338, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/root/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_19239/2623286357.py", line 32, in <cell line: 32>
#     model = DecagonModel(
#   File "/root/decagon/decagon/deep/model.py", line 62, in __init__
#     self.build()
#   File "/root/decagon/decagon/deep/model.py", line 36, in build
#     self._build()
#   File "/root/decagon/decagon/deep/model.py", line 67, in _build
#     self.hidden1[i].append(GraphConvolutionSparseMulti(
#   File "/root/decagon/decagon/deep/layers.py", line 82, in __init__
#     self.vars['weights_%d' % k] = inits.weight_variable_glorot(
#   File "/root/decagon/decagon/deep/inits.py", line 10, in weight_variable_glorot
#     initial = tf.random_uniform([input_dim, output_dim], minval=-init_range,
#   File "/root/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/root/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py", line 1082, in op_dispatch_handler
#     return dispatch_target(*args, **kwargs)
#   File "/root/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/random_ops.py", line 309, in random_uniform
#     result = gen_random_ops.random_uniform(
#   File "/root/anaconda3/lib/python3.9/site-packages/tensorflow/python/ops/gen_random_ops.py", line 737, in random_uniform
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "/root/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/op_def_library.py", line 740, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "/root/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 3776, in _create_op_internal
#     ret = Operation(
#   File "/root/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 2175, in __init__
#     self._traceback = tf_stack.extract_stack_for_node(self._c_op)

# %%
###########################################################
#
# Train model
#
###########################################################

print("Train model")
for epoch in range(FLAGS.epochs):

    minibatch.shuffle()
    itr = 0
    while not minibatch.end():
        # Construct feed dictionary
        feed_dict = minibatch.next_minibatch_feed_dict(placeholders=placeholders)
        feed_dict = minibatch.update_feed_dict(
            feed_dict=feed_dict,
            dropout=FLAGS.dropout,
            placeholders=placeholders)

        t = time.time()

        # Training step: run single weight update
        outs = sess.run([opt.opt_op, opt.cost, opt.batch_edge_type_idx], feed_dict=feed_dict)
        train_cost = outs[1]
        batch_edge_type = outs[2]

        if itr % PRINT_PROGRESS_EVERY == 0:
            val_auc, val_auprc, val_apk = get_accuracy_scores(
                minibatch.val_edges, minibatch.val_edges_false,
                minibatch.idx2edge_type[minibatch.current_edge_type_idx])

            print("Epoch:", "%04d" % (epoch + 1), "Iter:", "%04d" % (itr + 1), "Edge:", "%04d" % batch_edge_type,
                  "train_loss=", "{:.5f}".format(train_cost),
                  "val_roc=", "{:.5f}".format(val_auc), "val_auprc=", "{:.5f}".format(val_auprc),
                  "val_apk=", "{:.5f}".format(val_apk), "time=", "{:.5f}".format(time.time() - t))

        itr += 1

print("Optimization finished!")

for et in range(num_edge_types):
    roc_score, auprc_score, apk_score = get_accuracy_scores(
        minibatch.test_edges, minibatch.test_edges_false, minibatch.idx2edge_type[et])
    print("Edge type=", "[%02d, %02d, %02d]" % minibatch.idx2edge_type[et])
    print("Edge type:", "%04d" % et, "Test AUROC score", "{:.5f}".format(roc_score))
    print("Edge type:", "%04d" % et, "Test AUPRC score", "{:.5f}".format(auprc_score))
    print("Edge type:", "%04d" % et, "Test AP@k score", "{:.5f}".format(apk_score))
    print()
